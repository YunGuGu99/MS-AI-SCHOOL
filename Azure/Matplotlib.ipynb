# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Style 적용하기

# %%
plt.style.use('classic')

# %%
import numpy as np

# %% [markdown]
# Sample Data 생성

# %%
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
fig.savefig('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))
plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

# %%
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))
plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

# %%
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))
plt.subplot(2,1,2)
plt.plot(x, np.cos(x))
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))
plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

# %%
plt.style.use('seaborn-whitegrid')

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10,100)
ax.plot(x, np.sin(x))

# %% [markdown]
# 색상의 이름으로 지정
#
# 짧은 색상코드 RGB, CMYK
#
# 0-1사이에 회색조를 표현   //0.75
#
# 16진수로 표현한 RGB //#FFDD44
#
# RGB 값을 튜플로 표현 //(1.0, 0.2, 0.3)

# %%
plt.plot(x, np.sin(x-0), color='blue')      
plt.plot(x, np.sin(x-1), color='g')         
plt.plot(x, np.sin(x-2), color='0.75')                       
plt.plot(x, np.sin(x-3), color='#FFDD44')
plt.plot(x, np.sin(x-4), color='pink')
plt.plot(x, np.sin(x-5), color='purple')

# %% [markdown]
# dashe = 점선
#
# dashdot = -.-.(??)
#
# dotted = 작은 점선

# %%
plt.plot(x, x+0, linestyle='solid')
plt.plot(x, x+1, linestyle='dashed')
plt.plot(x, x+2, linestyle='dashdot')
plt.plot(x, x+3, linestyle='dotted')

plt.plot(x, x+4, linestyle='-')
plt.plot(x, x+5, linestyle='--')
plt.plot(x, x+6, linestyle='-.')
plt.plot(x, x+7, linestyle=':')

# %%
plt.plot(x, x+0, '-g')
plt.plot(x, x+1, '--c')
plt.plot(x, x+2, '-.k')
plt.plot(x, x+3, ':r')

# %% [markdown]
# 플롯 조정하기: 축 경계

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
# Out:
# (-1.0, 11.0)

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x))
plt.xlim(10, 0)
plt.ylim(1.2,-1.2)
# Out:
# (1.2, -1.2)

# %%
plt.plot(x, np.sin(x))
plt.axis([-1,11,-1.5,1.5])
# Out:
# (-1.0, 11.0, -1.5, 1.5)

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (0.0, 10.0, -0.9993845576124357, 0.9996923408861117)

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %% [markdown]
# 플롯에 레이블 붙이기

# %%
plt.plot(x, np.sin(x))
plt.title('A sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend()

# %% [markdown]
# 산점도의 출력

# %%
x = np.linspace(0,10,30)
y = np.sin(x)

plt.plot(x,y,'o', color='black')

# %%
rng = np.random.RandomState(0)
for marker in ['o',',','x','+','v','<','>','s','d']:
    plt.plot(rng.random(5), rng.random(5), marker, label='marker={0}'.format(marker))
    plt.legend()
    plt.xlim(0,1.8)

# %%
plt.plot(x,y,'-ok')

# %%
plt.plot(x,y,'-p', color='gray', markersize=15, 
         linewidth=4, markerfacecolor='white',
        markeredgecolor='red', markeredgewidth='2')

# %%
plt.scatter(x,y,marker='o', s=150)

# %%
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)
color = rng.randn(100)
size = 1000 * rng.randn(100)

plt.scatter(x,y, s=size, c= color, alpha=0.3, cmap='viridis')
plt.colorbar()
#viridis(색상표)(https://cran.microsoft.com/snapshot/2017-08-01/web/packages/viridis/vignettes/intro-to-viridis.html)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13252\990900501.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %% [markdown]
# sckit-learn

# %%
from sklearn.datasets import load_iris

iris = load_iris()

# %%
features = iris.data.T   #데이터 가져오기
iris.data.desc

# %%
plt.scatter(features[0],features[1],s=100 * features[3],c=iris.target,alpha=0.3,cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# 오차 시각화

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x,y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x,y,yerr=dy,fmt='o',color='black',ecolor='lightgray', elinewidth=3,
             capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>
